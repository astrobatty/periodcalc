# %%
import pandas as pd
import glob
import matplotlib.pyplot as plt

# %%
import os

# %%
# Install the PyDrive wrapper & import libraries.
# This only needs to be done once in a notebook.
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# %%
# Authenticate and create the PyDrive client.
# This only needs to be done once in a notebook.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
#import zastro as z
import numpy as np
from scipy import optimize
import matplotlib.pyplot as plt
import glob
import pandas as pd
#from uncertainties import ufloat
import numpy as np
import pandas as pd
import os
import warnings
from scipy.optimize import OptimizeWarning
import matplotlib.gridspec as gridspec
from astropy.stats import LombScargle
#from gatspy.periodic import LombScargleFast
import warnings

# %%
import pymc3 as pm
from pandas.plotting import scatter_matrix
import seaborn as sns

# %%
def file_len(fname):
    with open(fname) as f:
        for i, l in enumerate(f):
            pass
    return i + 1

# %%
def whitening(time, signaltowhiten, best_freq = False):
    dowewantplots=False
    
    #write out every 32th roughly:
  #  if (np.random.rand() > 0.5 and 
  #      np.random.rand() > 0.5 and
  #      np.random.rand() > 0.5 and
  #      np.random.rand() > 0.5 and 
  #      np.random.rand() > 0.5):
  #      
  #      dowewantplots = True
    
    #print(time)
    #print(signaltowhiten)
    

    if not best_freq:
        ls = LombScargle(time, signaltowhiten, nterms=1)
        #nyquist = len(time)/(2*(max(time)-min(time)))
        freq, power = ls.autopower(normalization='psd',nyquist_factor=1, samples_per_peak=10)

        if dowewantplots:
            plt.plot(freq, power);
            plt.show()

        best_freq = freq[power.argmax()]
        best_power = power[power.argmax()]
        signalfit = ls.model(time, best_freq)


        pfit, pcov = optimize.curve_fit(lambda time, amp, phase: sine(time, amp, best_freq, phase),
                                                     time, signalfit-np.mean(signalfit))
    else:
        pfit, pcov = optimize.curve_fit(lambda time, amp, phase: sine(time, amp, best_freq, phase),
                                                     time, signaltowhiten-np.mean(signaltowhiten))
    
    
    if dowewantplots: 
        
        plt.figure(figsize=(15,5))
        if not best_freq: 
            plt.plot(time, signalfit, alpha=0.5, c='b')

            plt.plot(np.linspace(min(time),max(time),10000),
                                                  np.mean(signalfit)+sine(np.linspace(min(time),max(time),10000),
                                                  pfit[0], # ez a fittelt ampli az LS fitre 
                                                  best_freq, 
                                                  pfit[1]),
                                                  c='r')

        else:
            plt.plot(np.linspace(min(time),max(time),10000),
                                                  np.mean(signaltowhiten)+sine(np.linspace(min(time),max(time),
                                                  10000),
                                                  pfit[0], # ez a fittelt ampli az LS fitre 
                                                  best_freq, 
                                                  pfit[1]),
                                                  c='r')

            
            
        plt.plot(time, signaltowhiten,alpha=0.5)
        #plt.plot(time, signaltowhiten-signalfit)
        plt.xlim(min(time),min(time)+1)
        #plt.xlim([2440,2450])
        plt.show()
    
    #powerstd = np.std(power)
    
    #return freq, power, signalfit, best_freq, best_power, powerstd
    
    if not best_freq:
        return (pfit[0], #amp
               pfit[1], # phase 
               best_freq, signalfit)
    else:
        return (pfit[0], pfit[1], best_freq, np.mean(signaltowhiten)+sine(BJD,
                                                  pfit[0], # ez a fittelt ampli az LS fitre 
                                                  best_freq, 
                                                  pfit[1]))
    
def sine(x,amp,freq,phase):
    return amp*np.sin(x*2*np.pi*freq + phase)

# %%
def fitter(filename):
    def F(x, A_0,
          A_1, phi_1,A_2, phi_2,A_3, phi_3,A_4, phi_4,A_5, phi_5,A_6, phi_6,freq):
        return (A_0+A_1*np.sin(2*np.pi*1*freq*x+phi_1)+
                    A_2*np.sin(2*np.pi*2*freq*x+phi_2)+
                    A_3*np.sin(2*np.pi*3*freq*x+phi_3)+
                    A_4*np.sin(2*np.pi*4*freq*x+phi_4)+
                    A_5*np.sin(2*np.pi*5*freq*x+phi_5)+
                    A_6*np.sin(2*np.pi*6*freq*x+phi_6))
    
    df=pd.read_csv(filename,sep=r"\s*")
    BJD=df.iloc[:,1]
    flux=df.iloc[:,6]
    fluxerror=df.iloc[:,7]
        
    model = LombScargleFast().fit(BJD, flux)
    
    NYQ=len(BJD)/(2*(max(BJD)-min(BJD)))
    periods, power = model.periodogram_auto(NYQ)
    model.optimizer.period_range=(0.1, 1.4)
    period = model.best_period
    print('##########')
    print(str(period))
    print('##########')
    
    
    LSPfreq=1/period

    pfit, pcov=optimize.curve_fit(lambda x, _A_0, 
                                      _A_1, _phi_1,
                                      _A_2, _phi_2,
                                      _A_3, _phi_3,
                                      _A_4, _phi_4,
                                      _A_5, _phi_5,
                                      _A_6, _phi_6,_freqfit:

                                      F(x, _A_0,_A_1, _phi_1,
                                                _A_2, _phi_2,
                                                _A_3, _phi_3,
                                                _A_4, _phi_4,
                                                _A_5, _phi_5,
                                                _A_6, _phi_6,_freqfit),

                                      BJD, flux, 
                                                 p0=[100, 100, 0,
                                                          100, 0,
                                                          100, 0,
                                                          100, 0,
                                                          100, 0,
                                                          100, 0,
                                                          LSPfreq],

                                                     sigma=fluxerror, absolute_sigma=True)

    error = [] # DEFINE LIST TO CALC ERROR
    for i in range(len(pfit)): 
        try:error.append(np.absolute(pcov[i][i])**0.5) # CALCULATE SQUARE ROOT OF TRACE OF COVARIANCE MATRIX
        except:error.append( 0.00 )     
    perr_curvefit = np.array(error)
    
    plt.figure(figsize=(20,8))
    plt.plot(BJD, flux)
    plt.plot(BJD, F(BJD, *pfit))
    plt.xlim(min(BJD),min(BJD)+5)
    plt.show()
    
    
    return BJD, flux, fluxerror, pfit, perr_curvefit, LSPfreq

# %%
def splitthem(inputBJD,inputflux,fluxerror,bar,n):
    df = pd.DataFrame({'BJD':inputBJD,'flux':inputflux,'fluxerror':fluxerror})
    dfbit=df[(df['BJD']<df['BJD'].iloc[0]+bar*(n+1)) & (df['BJD']>=df['BJD'].iloc[0]+bar*n)]
    dfbitlistBJD=dfbit['BJD'].tolist()
    dfbitlistflux=dfbit['flux'].tolist()
    dfbitlistfluxerror=dfbit['fluxerror'].tolist()
    if not dfbitlistBJD: raise ValueError("there arent that manyth period as you requested")
    return dfbitlistBJD, dfbitlistflux, dfbitlistfluxerror

# %%
def splitthem2(inputBJD, inputflux,fluxerror,span,step,n):
    df = pd.DataFrame({'BJD':inputBJD,'flux':inputflux,'fluxerror':fluxerror})
    dfbit=df[(df['BJD']<df['BJD'].iloc[0]+step*n+span) & (df['BJD']>=df['BJD'].iloc[0]+step*n)]
    dfbitlistBJD=dfbit['BJD'].tolist()
    dfbitlistflux=dfbit['flux'].tolist()
    dfbitlistfluxerror=dfbit['fluxerror'].tolist()
    if not dfbitlistBJD: raise ValueError("there arent that manyth period as you requested")
    return dfbitlistBJD, dfbitlistflux, dfbitlistfluxerror

# %%
def FFF(x, a0, a, psi, resdict):
        return (a0*resdict['A_0']+
                a*resdict['A_1']*np.sin(2*np.pi*1*resdict['freqfit']*x+resdict['phi_1']+1*psi)+
                a*resdict['A_2']*np.sin(2*np.pi*2*resdict['freqfit']*x+resdict['phi_2']+2*psi)+
                a*resdict['A_3']*np.sin(2*np.pi*3*resdict['freqfit']*x+resdict['phi_3']+3*psi)+
                a*resdict['A_4']*np.sin(2*np.pi*4*resdict['freqfit']*x+resdict['phi_4']+4*psi)+
                a*resdict['A_5']*np.sin(2*np.pi*5*resdict['freqfit']*x+resdict['phi_5']+5*psi))
               # a*resdict['A_6']*np.sin(2*np.pi*6*resdict['freqfit']*x+resdict['phi_6']+6*psi))

# %%
def get_stat(data):
    value=np.median(data)
    ep=np.percentile(data,84.1)-value
    em=value-np.percentile(data,15.9)
    return value,ep,em

# %%
# %matplotlib inline
#%%capture
warnings.filterwarnings("ignore")

#objlist=glob.glob("/home/szabopal/PycharmProjects/veszprem/veszprembe_vitt_geprol_fajlok/veszpremOC/TESS_RRLs/*txt")
#objlist=set(glob.glob('./RRL/ao-ind*txt'))
objlist=set(glob.glob('*txt'))-set(glob.glob('*extended_details_Attilarun.txt'))

mmampl=[];mmphase=[];medflux=[];deltaaerrors=[];deltapsierrors=[]


for index, line in enumerate(objlist):
    if os.path.isfile(line+'_OCdata_extended_details_Attilarun.txt'): continue
    
    dowewantplotshere = False
    calcLSofOC = True
    dowewantgreenmarker = True
    saveplots=True
    weneedtxtoutput=True

    #if index<5:
    #if True: # for debug
    #if index>300: # for debug

    #if index>0:
    if True:
        print(line)

        if file_len(line)<20000: # short cadencekre nem fut


            #df=pd.read_csv(line,sep=r"\t")
            df=pd.read_csv(line,sep=r"\s*")
            BJD=df.iloc[:,1]
            flux=df.iloc[:,6]
            fluxerror=df.iloc[:,7]


          #      BJD, flux, fluxerror, pfit, perr_curvefit, LSPfreq =fitter(line)

          #      (A_0,
          #       A_1, phi_1,
          #       A_2, phi_2,
          #       A_3, phi_3,
          #       A_4, phi_4,
          #       A_5, phi_5,
          #       A_6, phi_6,
          #       freqfit) = pfit


          #      (err_A_0,
          #       err_A_1,  err_phi_1,
          #       err_A_2,  err_phi_2,
          #       err_A_3,  err_phi_3,
          #       err_A_4,  err_phi_4,
          #       err_A_5,  err_phi_5,
          #       err_A_6,  err_phi_6,
          #       err_freqfit) = perr_curvefit

            resdict={}
             #   resdict['A_0']     =  pfit[0]
             #   resdict['A_1']     =  pfit[1]
             #   resdict['phi_1']   =  pfit[2]
             #   resdict['A_2']     =  pfit[3]
             #   resdict['phi_2']   =  pfit[4]
             #   resdict['A_3']     =  pfit[5]
             #   resdict['phi_3']   =  pfit[6]
             #   resdict['A_4']     =  pfit[7]
             #   resdict['phi_4']   =  pfit[8]
             #   resdict['A_5']     =  pfit[9]
             #   resdict['phi_5']   =  pfit[10]
             #   resdict['A_6']     =  pfit[11]
             #   resdict['phi_6']   =  pfit[12]
             #   resdict['freqfit'] =  pfit[13]

            amplist=[]
            freqlist=[]
            phaselist=[]

            residual = flux
            for x in range(5):
                if x==0:
                    amp, phase, freq, signalfit = whitening(BJD,residual)
                    LSPfreq = freq
                else:
                    amp, phase, freq, signalfit = whitening(BJD,residual,best_freq = (x+1)*freqlist[0])
                residual = residual - signalfit

                amplist.append(amp)
                freqlist.append(freq)
                phaselist.append(phase)

            resdict['A_0'] = np.mean(flux)
            resdict['A_1']     =  amplist[0]
            resdict['phi_1']   =  phaselist[0]
            resdict['A_2']     =  amplist[1]
            resdict['phi_2']   =  phaselist[1]
            resdict['A_3']     =  amplist[2]
            resdict['phi_3']   =  phaselist[2]
            resdict['A_4']     =  amplist[3]
            resdict['phi_4']   =  phaselist[3]
            resdict['A_5']     =  amplist[4]
            resdict['phi_5']   =  phaselist[4]
            resdict['freqfit'] =  freqlist[0]

            template=np.zeros_like(BJD)
            for x in range(5):
                template+=sine(BJD, amplist[x],freqlist[x],phaselist[x])

            plt.suptitle('Template')
            plt.scatter(BJD, flux)
            plt.plot(BJD, template+np.mean(flux))
            plt.plot(BJD, FFF(BJD, 1, 1, 0, resdict), c='r')
            plt.xlim(max(BJD)-2, max(BJD))
            plt.show()



            a_range=[];psi_range=[]

            BJDmidP=[]
            a0values=[]
            a0errorvalues=[]
            avalues=[]
            aerrorvalues=[]
            psivalues=[]
            psierrorvalues=[]
            c=0

            checkinf=0

            while True: 
                try:
                    bitBJD,bitflux,bitfluxerror=splitthem2(BJD,flux,fluxerror,3*1/LSPfreq,1/LSPfreq,c)
                    bitBJD = np.asarray(bitBJD)
                    bitflux = np.asarray(bitflux)
                    bitfluxerror = np.asarray(bitfluxerror)
                    c=c+1

                    #print(len(bitBJD))
                    if len(bitBJD)<20: continue

                    '''pfit, pcov=optimize.curve_fit(lambda x, a0, a, psi: FFF(x, a0, a, psi, resdict),
                                                      bitBJD,bitflux,
                                                      p0=[0.9,0.9,0.6],
                                                      sigma=bitfluxerror,absolute_sigma=True)
                    '''
                        
                    with pm.Model() as mdl_ols:
                        ## define Normal priors to give Ridge regression
                        a0 = pm.Uniform("a0", 0., 2.)
                        a = pm.Uniform("a", 0., 2.)
                        psi = pm.Uniform("psi", -1., 1.)

                        ## define model
                        yest = FFF(bitBJD, a0, a, psi, resdict)

                        ## define Normal likelihood with HalfCauchy noise (fat tails, equiv to HalfT 1DoF)
                        likelihood = pm.Normal("likelihood", mu=yest, sigma=bitfluxerror, observed=bitflux)

                        #Populate MCMC sampler
                        traces = pm.sample(1000,chains=1)
                            
                    a0, a0ep, a0em = get_stat(traces['a0'])
                    a, aep, aem = get_stat(traces['a'])
                    psi, psiep, psiem = get_stat(traces['psi'])
                        
                    pfit = []
                    pfit.append( a0 )
                    pfit.append( a )
                    pfit.append( psi )
                        
                    perr_curvefit = []
                    perr_curvefit.append( (a0ep+a0em)/2. )
                    perr_curvefit.append( (aep+aem)/2. )
                    perr_curvefit.append( (psiep+psiem)/2. )
                        
                    if dowewantplotshere:
                        df_trace = pm.trace_to_dataframe(traces)
                        _ = sns.pairplot(df_trace)

                    #print('hali, ez itt pfit ketto')
                    #print(pfit[2])

                      #  pfit, pcov=optimize.curve_fit(lambda x, a0, a: FFF(x, a0, a,
                      #                                                     0, # ez a psi
                      #                                                     resdict),
                      #                                bitBJD,bitflux,
                      #                                #p0=[1,1,0],
                      #                                sigma=bitfluxerror,absolute_sigma=True)


                    '''error = [] # DEFINE LIST TO CALC ERROR
                    for i in range(len(pfit)): 
                        try:error.append(np.absolute(pcov[i][i])**0.5) # CALCULATE SQUARE ROOT OF TRACE OF COVARIANCE MATRIX
                        except:error.append( 0.00 )     
                    perr_curvefit = np.array(error)
                    '''
                    BJDmidP.append(np.min(bitBJD)+(np.max(bitBJD)-np.min(bitBJD))/2)

                    a0values.append(pfit[0])
                    a0errorvalues.append(perr_curvefit[0])

                    avalues.append(pfit[1])
                    aerrorvalues.append(perr_curvefit[1])

                    psivalues.append(pfit[2])
                    #psivalues.append(0)

                    psierrorvalues.append(perr_curvefit[2])         
                    #psierrorvalues.append(0)         

                    for each in perr_curvefit:
                        if np.isinf(each)==True:
                            checkinf+=1            

                    if dowewantplotshere:

                        plt.figure()
                        plt.suptitle('Fit to subsample')
                        plt.scatter(bitBJD,bitflux)

                        xxxx =np.linspace(min(bitBJD),max(bitBJD),1000)



                        plt.plot(xxxx,FFF(xxxx, pfit[0], pfit[1], pfit[2], resdict))

                        #plt.plot(xxxx,FFF(xxxx, pfit[0], pfit[1],0, resdict))



                        #plt.plot(xxxx,FFF(xxxx, 1, 1, 0, resdict))
                        plt.show()
                        #print('bitBJD az ez:')
                        #print(bitBJD)
                        # print(pfit[0],pfit[1],pfit[2])
                        # print(resdict)


                        # print('az fff:')
                        # print(FFF(bitBJD, pfit[0], pfit[1], pfit[2], resdict))

                except ValueError as err:
                    break

                except TypeError as err:
                    continue

            freqfit = LSPfreq
            period=1/freqfit
            periodarray=[period]*len(BJD)
            #BJDmodP=np.mod(BJD,periodarray)
            BJDmodP=[each%period for each in BJD]
            #BJDmodP_extended=BJDmodP.tolist()+(BJDmodP+periodarray).tolist()
            BJDmodP_extended=BJDmodP+(np.asarray(BJDmodP)+np.asarray(periodarray)).tolist()
            #flux_extended=flux.tolist()*2
            flux_extended=flux.tolist()*2

            nyquist=(max(BJDmidP)-min(BJDmidP))/len(BJDmidP)/2

            BJDmidP_frequency, avalues_power   = LombScargle(BJDmidP, avalues).autopower()
            highest_frequency_peak_in_avalues_power = BJDmidP_frequency[np.where(
                avalues_power==max(avalues_power[BJDmidP_frequency<nyquist]))[0][0]]

            avalues_maxpower = max(avalues_power[BJDmidP_frequency<nyquist])

            BJDmidP_frequency, psivalues_power = LombScargle(BJDmidP, psivalues).autopower()
            #plt.plot(BJDmidP_frequency, psivalues_power)

            if calcLSofOC:
                highest_frequency_peak_in_psivalues_power = BJDmidP_frequency[np.where(
                        psivalues_power==max(psivalues_power[BJDmidP_frequency<nyquist]))[0][0]]

                psivalues_maxpower=max(psivalues_power[BJDmidP_frequency<nyquist])

            #    highest_frequency_peak_in_psivalues_power = BJDmidP[np.where(psivalues_power==max(psivalues_power))[0][0]]


            _, ax = plt.subplots(nrows=1, ncols=4, figsize=(24,4), gridspec_kw = {'width_ratios':[1, 2, 2, 2]})        
            #ax[0].set_aspect(0.7)
            ax[0].scatter(BJDmodP_extended,flux_extended,s=1)
            ax[0].set_xlim([0,period*1.5])
            ax[0].set_xlabel("BJDmodP")
            ax[0].set_ylabel("flux")

            ax[1].plot(BJD,flux)
            ax[1].set_xlabel("BJD")
            ax[1].set_title(line)

            #ax[1].set_ylabel("flux")

            ax[2].errorbar(BJDmidP,a0values,a0errorvalues,c='g',label="a0")
            ax[2].errorbar(BJDmidP,avalues,aerrorvalues,c='r',label="a")
            ax[2].set_xlabel("BJD")
            ax[2].set_ylim([0.6,1.4])
            ax[2].set_title(str(round(period,8)),fontsize=20)

            ax2b=ax[2].twinx()
            ax2b.errorbar(BJDmidP,psivalues,psierrorvalues,label="psi")
            #ax2b.set_ylim([-0.09,0.09])
            ax2b.set_ylim([-0.14,0.14])

            ax[2].legend(loc='upper left')
            ax2b.legend(loc='upper right')

            if calcLSofOC:

                ax[3].plot(BJDmidP_frequency, avalues_power)
                ax[3].plot(BJDmidP_frequency, psivalues_power)
                ax[3].set_xlim([0, nyquist])
                ax[3].axvline(x=highest_frequency_peak_in_avalues_power,c='r',alpha=0.5)
                ax[3].axvline(x=highest_frequency_peak_in_psivalues_power,c='r',alpha=0.5)


            _.subplots_adjust(wspace=0.08)

            psi_range.append(np.max(psivalues)-np.min(psivalues))
            a_range.append(np.max(avalues)-np.min(avalues))

            if dowewantgreenmarker:
                if checkinf!=0:
                    ax[2].set_facecolor('xkcd:mint green')
                    ax[2].set_title("ESTIMATION OF ERRORS WENT WRONG")

            if saveplots:
                plt.savefig(line+"_Attilarun.png")

            plt.show()

            mmampl.append(np.abs(np.max(avalues)-np.min(avalues)))
            mmphase.append(np.abs(np.max(psivalues)-np.min(psivalues)))

            if checkinf==0:
                aerrorup=aerrorvalues[avalues.index(np.max(avalues))]
                aerrordown=aerrorvalues[avalues.index(np.min(avalues))]
            else:
                aerrorup=0
                aerrordown=0

            deltaaerrors.append(((aerrorup)**2+(aerrordown)**2)**0.5)      

            if checkinf==0:
                psierrorup=psierrorvalues[psivalues.index(np.max(psivalues))]
                psierrordown=psierrorvalues[psivalues.index(np.min(psivalues))]
            else:
                psierrorup=0
                psierrordown=0

            deltapsierrors.append(((psierrorup)**2+(psierrordown)**2)**0.5)


            medflux.append(np.median(flux))        

            if weneedtxtoutput:    
                fout=open(line+'_OCdata_extended_details_Attilarun.txt','w')
                fout.write('period '+str(period)+'\n')
                if calcLSofOC:
                    fout.write('LS_of_a_values_dominant_peak '+str(highest_frequency_peak_in_avalues_power)+'\n')
                    fout.write('LS_of_psi_values_dominant_peak '+str(highest_frequency_peak_in_psivalues_power)+'\n')
                fout.write('avalues_maxpower '+str(avalues_maxpower)+'\n')
                fout.write('psivalues_maxpower '+str(psivalues_maxpower)+'\n')
                fout.write('TIME AVALS PSIVALS\n')
                for index, each in enumerate(BJDmidP):
                    fout.write(str(each)+' '+str(avalues[index])+' '+str(psivalues[index])+'\n')
                fout.close()

            try:    
              
              # Create & upload a file.
              uploaded = drive.CreateFile({'title': line+"_Attilarun.png"})
              uploaded.SetContentFile(line+"_Attilarun.png")
              uploaded.Upload()
              print('Uploaded file with ID {}'.format(uploaded.get('id')))
              uploaded = drive.CreateFile({'title': line+'_OCdata_extended_details_Attilarun.txt'})
              uploaded.SetContentFile(line+'_OCdata_extended_details_Attilarun.txt')
              uploaded.Upload()
              print('Uploaded file with ID {}'.format(uploaded.get('id')))
              
            except InvalidConfigError:
              
              # Authenticate and create the PyDrive client.
              # This only needs to be done once in a notebook.
              auth.authenticate_user()
              gauth = GoogleAuth()
              gauth.credentials = GoogleCredentials.get_application_default()
              drive = GoogleDrive(gauth)
              
              # Create & upload a file.
              uploaded = drive.CreateFile({'title': line+"_Attilarun.png"})
              uploaded.SetContentFile(line+"_Attilarun.png")
              uploaded.Upload()
              print('Uploaded file with ID {}'.format(uploaded.get('id')))
              uploaded = drive.CreateFile({'title': line+'_OCdata_extended_details_Attilarun.txt'})
              uploaded.SetContentFile(line+'_OCdata_extended_details_Attilarun.txt')
              uploaded.Upload()
              print('Uploaded file with ID {}'.format(uploaded.get('id')))
                
        #   with open(line+'_OCdata_extended_details.txt','a') as f:
        #       f.write('\n# This file was created by:\n')
        #       f.write('# '+get_notebook_name()+'\n')
        #       f.write('# Computer:\n')
        #       f.write('# CSFK\n')
        #       f.write('# System time:\n')
        #       f.write('# '+str(datetime.datetime.now())+'\n')
        #       f.write('# Code also available here:\n')
        #       f.write('# ps738@shell.srcf.net:/home/ps738/konkoly/'+get_notebook_name().split('/')[-1]+'\n')
        #       f.write('# Pal Szabo')

    #os.environ['thisnotebook']=get_notebook_name()
    #!scp -i ~/.ssh/zabop $thisnotebook ps738@shell.srcf.net:/home/ps738/konkoly
# Out:
# sz-men-s12-rp.txt
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:03<00:00, 456.51it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:03<00:00, 494.38it/s]
# The acceptance probability does not match the target. It is 0.8814637180745097, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 616.41it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 501.86it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:03<00:00, 496.21it/s]
# The acceptance probability does not match the target. It is 0.8862079436882259, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 600.29it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 523.99it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:03<00:00, 462.07it/s]
# The acceptance probability does not match the target. It is 0.8857580546083192, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 518.40it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 682.95it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:03<00:00, 447.98it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 559.94it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:03<00:00, 411.13it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:04<00:00, 374.20it/s]
# The acceptance probability does not match the target. It is 0.8929114419163495, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 597.00it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 549.47it/s]
# The acceptance probability does not match the target. It is 0.8890241273819359, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:03<00:00, 571.94it/s]
# The acceptance probability does not match the target. It is 0.8907686315612534, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:04<00:00, 369.88it/s]
# The acceptance probability does not match the target. It is 0.9046945410114977, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 603.84it/s]
# The acceptance probability does not match the target. It is 0.8813500448654759, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:03<00:00, 449.23it/s]
# The acceptance probability does not match the target. It is 0.8795555859980045, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:04<00:00, 300.67it/s]
# The acceptance probability does not match the target. It is 0.8978342171854686, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 504.43it/s]
# The acceptance probability does not match the target. It is 0.8837472811509369, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 542.17it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 561.39it/s]
# The acceptance probability does not match the target. It is 0.8965034237520034, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 686.12it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 607.66it/s]
# The acceptance probability does not match the target. It is 0.895793973245919, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:03<00:00, 443.19it/s]
# The acceptance probability does not match the target. It is 0.8923245582344045, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:03<00:00, 476.94it/s]
# The acceptance probability does not match the target. It is 0.8865336713665429, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:04<00:00, 371.65it/s]
# The acceptance probability does not match the target. It is 0.898655586580534, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 527.00it/s]
# The acceptance probability does not match the target. It is 0.8917548492431767, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:03<00:00, 435.31it/s]
# The acceptance probability does not match the target. It is 0.8956264662202723, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:04<00:00, 359.98it/s]
# The acceptance probability does not match the target. It is 0.9024959919474488, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:03<00:00, 425.37it/s]
# The acceptance probability does not match the target. It is 0.8951462526265589, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 642.34it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:03<00:00, 389.65it/s]
# The acceptance probability does not match the target. It is 0.8932703145374933, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 543.99it/s]
# The acceptance probability does not match the target. It is 0.8802167087671028, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:03<00:00, 473.50it/s]
# The acceptance probability does not match the target. It is 0.8848320247295431, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:03<00:00, 424.52it/s]
# The acceptance probability does not match the target. It is 0.8902478922735716, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:04<00:00, 361.40it/s]
# The acceptance probability does not match the target. It is 0.9024742486146122, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 687.12it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 562.01it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:04<00:00, 359.74it/s]
# The acceptance probability does not match the target. It is 0.8819832055534595, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 630.37it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 503.76it/s]
# The acceptance probability does not match the target. It is 0.8862671463590611, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:03<00:00, 454.77it/s]
# The acceptance probability does not match the target. It is 0.8903068004239377, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 568.34it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:03<00:00, 402.38it/s]
# The acceptance probability does not match the target. It is 0.8831617497128431, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:03<00:00, 421.69it/s]
# The acceptance probability does not match the target. It is 0.8849911944053042, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:03<00:00, 456.01it/s]
# The acceptance probability does not match the target. It is 0.8828765939369427, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:03<00:00, 495.66it/s]
# The acceptance probability does not match the target. It is 0.8953657252820278, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 633.95it/s]
# The acceptance probability does not match the target. It is 0.8857439151239829, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:01<00:00, 776.63it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:03<00:00, 461.75it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 584.15it/s]
# The acceptance probability does not match the target. It is 0.8826608117033711, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:03<00:00, 456.36it/s]
# The acceptance probability does not match the target. It is 0.8809546486476575, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 534.63it/s]
# The acceptance probability does not match the target. It is 0.8787008985433767, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 520.86it/s]
# The acceptance probability does not match the target. It is 0.8824774107590987, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:03<00:00, 476.13it/s]
# The acceptance probability does not match the target. It is 0.8883369581130836, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 580.94it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 519.24it/s]
# The acceptance probability does not match the target. It is 0.8910901315162023, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:03<00:00, 478.35it/s]
# The acceptance probability does not match the target. It is 0.8839320406795628, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 595.29it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 573.80it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 516.73it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 590.78it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 585.94it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:04<00:00, 341.91it/s]
# The acceptance probability does not match the target. It is 0.8892511311745639, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 602.53it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:03<00:00, 474.36it/s]
# The acceptance probability does not match the target. It is 0.8944711616356955, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 563.56it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 590.49it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 538.30it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 512.90it/s]
# The acceptance probability does not match the target. It is 0.8828920556635051, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:03<00:00, 469.35it/s]
# The acceptance probability does not match the target. It is 0.8898304120897806, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 575.01it/s]
# The acceptance probability does not match the target. It is 0.8874986949460981, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 628.09it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:01<00:00, 756.44it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 732.32it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 611.43it/s]
# The acceptance probability does not match the target. It is 0.8856256560810131, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:03<00:00, 390.31it/s]
# The acceptance probability does not match the target. It is 0.8917720460724794, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:03<00:00, 382.64it/s]
# The acceptance probability does not match the target. It is 0.8907313281330721, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:03<00:00, 493.07it/s]
# The acceptance probability does not match the target. It is 0.8948286187486337, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 590.20it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 501.97it/s]
# The acceptance probability does not match the target. It is 0.8919444377120697, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:03<00:00, 495.88it/s]
# The acceptance probability does not match the target. It is 0.8792226948208429, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:03<00:00, 427.20it/s]
# The acceptance probability does not match the target. It is 0.8925432955246008, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 544.94it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 667.73it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:03<00:00, 429.80it/s]
# The acceptance probability does not match the target. It is 0.8843340838388827, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:03<00:00, 493.32it/s]
# The acceptance probability does not match the target. It is 0.889358931877104, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 608.28it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 528.25it/s]
# The acceptance probability does not match the target. It is 0.8815562796293704, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:03<00:00, 465.26it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:03<00:00, 489.56it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:03<00:00, 485.23it/s]
# The acceptance probability does not match the target. It is 0.8844817118217905, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:04<00:00, 366.00it/s]
# The acceptance probability does not match the target. It is 0.8920394902669322, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 661.80it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:03<00:00, 452.61it/s]
# The acceptance probability does not match the target. It is 0.8914401222713736, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:03<00:00, 443.09it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 601.87it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 585.74it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:03<00:00, 491.05it/s]
# The acceptance probability does not match the target. It is 0.8856635147411266, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 617.57it/s]
# The acceptance probability does not match the target. It is 0.8816151064580704, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Uploaded file with ID 1_eom5tMXd2aAk3OdrGweyL2C3w7cSAaL
# Uploaded file with ID 1R5CmJpGc45iUbj_T5c88LW2PnikjVuqR
# LMC-RRLYR-23457-s12-rp.txt
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 549.07it/s]
# The acceptance probability does not match the target. It is 0.8860418633309805, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 636.53it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 581.94it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:03<00:00, 490.06it/s]
# The acceptance probability does not match the target. It is 0.880271267102619, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 577.04it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 542.83it/s]
# The acceptance probability does not match the target. It is 0.8823987952137704, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 552.05it/s]
# The acceptance probability does not match the target. It is 0.8881731819168659, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 592.40it/s]
# The acceptance probability does not match the target. It is 0.8846927345418398, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 611.22it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 601.86it/s]
# The acceptance probability does not match the target. It is 0.8835476554915267, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 542.51it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 613.81it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 510.22it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:03<00:00, 473.90it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 540.07it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 587.00it/s]
# The acceptance probability does not match the target. It is 0.8877779341472256, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 559.37it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 612.81it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 663.45it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 568.18it/s]
# The acceptance probability does not match the target. It is 0.8837310243061051, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 558.47it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 564.91it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 730.09it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 650.80it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 671.98it/s]
# The acceptance probability does not match the target. It is 0.882901955523475, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 675.36it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:03<00:00, 491.40it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:03<00:00, 484.36it/s]
# The acceptance probability does not match the target. It is 0.882851660904763, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 762.85it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:03<00:00, 480.51it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:03<00:00, 496.77it/s]
# The acceptance probability does not match the target. It is 0.8817708669940303, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 509.71it/s]
# The acceptance probability does not match the target. It is 0.8861090900860261, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 557.69it/s]
# The acceptance probability does not match the target. It is 0.88867527427842, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 517.94it/s]
# The acceptance probability does not match the target. It is 0.8862132739569658, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 650.21it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 570.87it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 623.95it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 509.40it/s]
# The acceptance probability does not match the target. It is 0.8808731545421665, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 745.58it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 641.62it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 574.50it/s]
# The acceptance probability does not match the target. It is 0.886003732790448, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 512.02it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:03<00:00, 414.21it/s]
# The acceptance probability does not match the target. It is 0.8808493740674463, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 608.78it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:03<00:00, 465.96it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 632.50it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 551.69it/s]
# The acceptance probability does not match the target. It is 0.880815768725191, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:03<00:00, 491.32it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 624.82it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 691.73it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 723.07it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 606.05it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 572.13it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 545.12it/s]
# The acceptance probability does not match the target. It is 0.8821923892541395, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 646.89it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 549.24it/s]
# The acceptance probability does not match the target. It is 0.8821198299797038, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 618.65it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 557.85it/s]
# The acceptance probability does not match the target. It is 0.8854489801782875, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 601.66it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 645.34it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 554.65it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 564.51it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 531.94it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 598.72it/s]
# The acceptance probability does not match the target. It is 0.8839837589616208, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 656.09it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 571.01it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 549.98it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 588.86it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 546.56it/s]
# The acceptance probability does not match the target. It is 0.8854040785192346, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 509.12it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 653.81it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 579.84it/s]
# The acceptance probability does not match the target. It is 0.881069198822088, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:03<00:00, 449.12it/s]
# The acceptance probability does not match the target. It is 0.8828793602666554, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 589.00it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 529.66it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 629.05it/s]
# The acceptance probability does not match the target. It is 0.8839649448219039, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:02<00:00, 634.12it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [psi, a, a0]
# 100%|██████████| 1500/1500 [00:03<00:00, 499.63it/s]
# The acceptance probability does not match the target. It is 0.8787519024483306, but should be close to 0.8. Try to increase the number of tuning steps.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
